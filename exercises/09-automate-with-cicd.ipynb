# %% [markdown]
# # Automation with CI/CD ⚙️
#
# We got the building blocks to evaluate and deploy our solution, but we're still running everything manually. Let's change that.
#
# In this notebook, we will develop a CI/CD pipeline in [Github Actions](https://github.com/features/actions) which evaluates and deploys our solution automatically.

# %% [markdown]
# 🚨 **NOTE**: For this exercise we've given you _write_ access on the repository. It's important that you create your personal branch before pushing to the repository. Please do **NOT** push your code to the `main` branch.
#
# > **Instructions for creating your own branch**:
# >
# > 1. Open a terminal
# > 2. Run `git checkout -b llmops-training-<your-name>` (if you haven't done so already)
# > 3. That's it! You can check if all went well by looking at the bottom left corner in VSCode. It should show the branch you're currently on.

# %% [markdown]
# ## Continuous Integration
#
# For the CI part, it's important that we run code quality checks and tests before code is integrated into the main branch.
#
# > **Exercise 📝**
# >
# > - Inspect the provided `ci.yaml` file in the `.github/workflows` directory.
# > - Fill in the TODO's to make sure the code quality checks and tests are run when the pipeline runs
# > - Choose a trigger for the pipeline to run. Best is to choose your own branch for now, as we will not be pushing to `main`.
# >
# > 💡 Tip:
# >
# > - If you're running short on time, it's more fun to skip this part and jump to the CD part. You can always come back to this later.

# %% [markdown]
# ## Continuous Delivery
#
# For the CD part, we will execute all the steps from building our container to deploying it to Azure Container Apps.
#
# > **Exercise 📝**
# >
# > - Inspect the provided `cd.yaml` file in the `.github/workflows` directory.
# > - Fill in the TODO's to make sure the container is built, pushed and deployed to Azure Container Apps when the pipeline runs
# > - Choose a trigger for the pipeline to run. Best is to choose your own branch for now, as we will not be pushing to `main`.
# > - Trigger the pipeline and see if it indeed deploys a new revision to Azure Container Apps. 🎉
