# %% [markdown]
# # Running the app 💻
#
# We've explored the logic behind our solution, now let's run the app in which will serve our solution to the user.
#
# For now, we will use placeholders `mock_extract_article_info` and `mock_extract_info_from_articles` to simulate the extraction of information from the articles.
#
# In the notebook after this one, we will replace these placeholders with the actual functions that will extract the information from the articles.

# %% [markdown]
# We are using [streamlit](https://streamlit.io/) to serve our app. Streamlit is a great tool for quickly building web apps with Python.
#
#
# > **Exercise** 📝
# >
# > - Explore `app.py` in the `app` directory in our package. This is the entry point of our streamlit app.
# > - Explore the `components` module in the same directory. This is where we define the components of our app.
# > - Run the app by executing the following command in the terminal:
# >   ```bash
# >   uv run streamlit run src/llmops_training/news_reader/app/app.py
# >   ```
#
# Now, you can try uploading some articles (see `tests/articles`), but it will probably say "An error occurred while processing this article." because we haven't implemented the logic to extract information from the articles yet.

# %% [markdown]
# > **Exercise** 📝
# > - Fill in the TODO's `# TODO(03-running-the-app)` in `components.py` to (mock) extract structured information from the uploaded articles. Use the `mock_extract_info_from_articles` function.
# > - Now, run the app again, upload some articles and see the (mocked) structured information extracted from them.
